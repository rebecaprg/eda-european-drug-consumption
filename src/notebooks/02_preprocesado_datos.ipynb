# %% [markdown]
# En este notebook se incluye:
#
# 3. Documentar el origen de cada fuente de datos
#
# En primar lugar, es preciso establecer que no ha sido necesario realizar el proceso de unificación de diversos datasets ya que el presente análisis dispone de una única fuente de datos y, por ende, un único dataset. Por ello, el dataset que se ha utilizado está centralizado desde su origen.
#
# Por otro lado, la **fuente de datos** utilizada en este EDA ha sido la European Union Drugs Agency (EUDA), el cual constituye un organismo oficial de la Unión Europea y que, por ende, se garantiza la calidad metodológica, fiabilidad y comparabilidad de los datos utilizados. En concreto, la EUDA dispone del informe European Drug Report 2023 dentro de la sección Source data - Cocaine (URL: https://www.euda.europa.eu/data/source-data/edr/2023/cocaine_en).
#
# Concretamente, se ha utilizado la tabla "Prevalence of drug use in Europe, based on most recent general population surveys (2021 or most recent year)". Ésta presenta varias filas, donde cada una representa observaciones correspondientes a cada país. Por su parte, las columnas representarían variables, como la prevalencia del consumo en función al tipo de sustancia, el género o la edad del individuo consumidor. Su formato nos permite realizar operciones tales como la limpieza, visualización y exploración de datos eficientemente.
#
#
#
#
#
#
# Este notebook también incluiría (no nos hace falta):
# 1. Unir los datos en un único dataset (si procede)
#
# 2. convertir a formato estructurado
